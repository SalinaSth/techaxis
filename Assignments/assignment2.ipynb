# %% [markdown]
# ## Topics: List-operations, slicing comprehension
# ### Task 1

# %%
user_input = list(input("Enter a list of number:"))
print('user input -----',user_input)
even_num = []
# [ele % 2 ===]
for ele in user_input:
    print('wwwwwwwww', ele)
    if isinstance(ele, int | float):
        evn = int(ele) % 2 == 0
        even_num.append(evn)
        print('kkkkkkkkkk', evn)

    #     print('ddddd',evn)
    # else:
    #     evn = ele
print('=============',even_num, ele, evn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 user_input = list(int(input("Enter a list of number:")))
#       2 print('user input -----',user_input)
#       3 even_num = []
#
# TypeError: 'int' object is not iterable
