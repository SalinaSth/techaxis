# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 'B': ['B0', 'B1', 'B2']})
df2 = pd.DataFrame({'A': ['A3', 'A4', 'A5'], 'B': ['B3', 'B4', 'B5']})

# merge
df1 = pd.DataFrame({'key': ['K0', 'K1', 'K2'], 'A': ['A0', 'A1', 'A2']})
df2 = pd.DataFrame({'key': ['K1', 'K2', 'K3'], 'B': ['B1', 'B2', 'B3']})

df3 = pd.DataFrame({'C': ['C0', 'C1', 'C2', 'C4']})

df1 = pd.DataFrame({'name': ['A', 'B', 'C'], 'points': [8, 12, 19], 'common': [1, 2, 3]})
df2 = pd.DataFrame({'name': ['A', 'B', 'C'], 'steals': [4, 5, 2], 'common': [4, 5, 6]})

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2']}, index=['K0', 'K1', 'K2'])
df2 = pd.DataFrame({'B': ['B1', 'B2', 'B3']}, index=['K1', 'K2', 'K3'])
