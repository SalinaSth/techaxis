# %% [markdown]
# # String

# %%
str1 = 'This is a note.'
str2 = "this is a note"
str3 = '''this is a note''' # multiline string
str4 = """this is a note"""

# %%
str5 = 'It\'s my book.' # escape character : \'
str6 = "It's my book, \"the book\"."

# %% [markdown]
# ## String Manipulation

# %%
str1 = 'it is a book'
str1.capitalize()
# Out:
# 'It is a book'

# %%
str1 = "IT IS A BOOK"
str1.capitalize()
# Out:
# 'It is a book'

# %%
str1 = 'THis is BooK'
str1.casefold()
# Out:
# 'this is book'

# %%
str1 = 'THis is BooK'
str1.lower()
# Out:
# 'this is book'

# %%
str1 = 'THis is BooK'
str1.upper()
# Out:
# 'THIS IS BOOK'

# %%
str1 = 'THis is BooK'
str1.startswith('T')
# Out:
# True

# %%
str1.startswith('THis ')
# Out:
# True

# %%
str1.endswith('ooK')
# Out:
# True

# %%
str1 = '         THis is BooK       '
str1.strip()
# str1
# Out:
# 'THis is BooK'

# %%
str1.lstrip()
# Out:
# 'THis is BooK       '

# %%
str1.rstrip()
# Out:
# '         THis is BooK'

# %%
str1 = 'This is a Book. I like it. This book has 500 pages.'
str1.split(".")
# Out:
# ['This is a Book', ' I like it', ' This book has 500 pages', '']

# %%
str2 = ['This is a Book', ' I like it', ' This book has 500 pages', '']
'.'.join(str2)
# Out:
# 'This is a Book## I like it## This book has 500 pages##'

# %%
str1 = 'This is a Book. I like it. This book has 500 pages.'
str1.partition('and') # only splits in first occurence
# Out:
# ('This is a Book', '.', ' I like it. This book has 500 pages.')

# %%
str1 = "Hello %s"%'Tech'
str1
# Out:
# 'Hello Tech'

# %%
# for placeholder and later usage
str1 = 'Hello {name}, Welcome on {day}'

# %%
str1.format(name = 'name', day = 'Monday')
# Out:
# 'Hello name, Welcome on Monday'

# %%
str1.format_map({'name': 'tech', 'day': 'Tuesday'})
# Out:
# 'Hello tech, Welcome on Tuesday'

# %%
# if variable value already available then use f string
name = 'Tech'
day = 'Wenesday'
str1 = f"Hello {name}. Welcome on {day}"
str1
# Out:
# 'Hello Tech. Welcome on Wenesday'

# %%
str1 = 'abcbdfbvsjfvhads'
str1.isalpha()
# Out:
# True

# %%
str1 = 'abc1232'
str1.isalpha()
# Out:
# False

# %%
str1 = 'abc1232'
str1.isalnum()
# Out:
# True

# %%
str1 = '1234'
str1.isnumeric()
# Out:
# True

# %%
str1.isdigit()
# Out:
# True

# %%
str1.isdecimal()
# Out:
# True

# %%
str1 = 'THis is a Book.'
title_str = str1.title()
title_str
# Out:
# 'This Is A Book.'

# %%
title_str.istitle()
# Out:
# True

# %%
str1 = 'This is a Book. I like it. This book has 500 pages. this is new book'
str1.replace('Book', 'note').replace('book', 'copy')
# Out:
# 'This is a note. I like it. This copy has 500 pages. this is new copy'

# %%
for ele in ['Book', 'book']:
    str1 = str1.replace(ele,'copy')
str1
# Out:
# 'This is a copy. I like it. This copy has 500 pages. this is new copy'

# %%
for k, v in {'Book': 'copy', 'book': 'copy', 'this': 'That'}.items():
    str1 = str1.replace(ele,'copy')
str1
# Out:
# 'This is a Book. I like it. This copy has 500 pages. this is new copy'

# %% [markdown]
# # Regex

# %%
import re

# %%
# match
match = re.match
#findall
#compile
