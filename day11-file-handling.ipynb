# %% [markdown]
# ## File Handling

# %%
# open('temp.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 open('temp.txt', 'r')
#
# File d:\anoconda\envs\tech-axis\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp.txt'

# %%
# forward slash = /, backward slash = \\
# filepath = 'E:\TECH-AXIS\ClassTech\Class1\data\temp.txt'
filepath = 'data/temp.txt'

# %%
file = open(filepath, 'r')

# %%
content = file.read()
content
# Out:
# 'This statement is numercally typed.'

# %%
file.close()

# %% [markdown]
# # Write operation

# %%
filepath = 'data/filewrite.txt'

# %%
file = open(filepath, 'w') #write mode
# file.write("This statement is written during write operation.")

# %%
file.write("This statement is second written during write operation.")

# %%
file.close()

# %% [markdown]
# ### `append` mode ('a')

# %%
filepath = 'data/file-append.txt'

# %%
file = open(filepath, 'a')

# %%
file.write("this is first statement")
file.close()

# %%
file = open(filepath, 'a')
file.write(". \nthis is second statement")
file.close()

# %%
file = open(filepath, 'a')
file.write("\nthis is third statement")
file.close()

# %% [markdown]
# ### `read` operation

# %%
filepath = 'data/file-append.txt'

# %%
file = open(filepath, 'r')

# %%
content = file.read()
content
# Out:
# 'this is first statementthis is second statement. this is second statement\nthis is third statement'

# %%
file.close()

# %%
file = open(filepath, 'r')
lines = file.readlines()
lines
# Out:
# ['this is first statementthis is second statement. this is second statement\n',
#  'this is third statement. \n',
#  'this is second statement']

# %%
file.close()

# %% [markdown]
# read mode -> 'r'
#
# write mode -> 'w'
#
# append mode ->'a'

# %% [markdown]
# ### File handling with context manager
# (with) don't have manually close

# %%
filepath = 'data/techaxis.txt'

# %%
# file = open(filepath, 'r')
with open(filepath, 'w') as file:
    file.write("This is written from context manager. \n")

# %%
with open(filepath, 'a') as file2:
    file2.write('This is second time writing from context manager\n')

# %%
with open(filepath, 'a') as file2:
    file2.writelines([
        'first\n',
        'second\n'
        'third'
    ])
