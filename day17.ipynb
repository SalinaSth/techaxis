# %%
import numpy as np

# %%
# nan - not a number 
# inf = infinity
np.nan, np.inf
# Out:
# (nan, inf)

# %%
a1 = np.array(([1, 2, 3, np.nan, 5, 6]))
a1
# Out:
# array([ 1.,  2.,  3., nan,  5.,  6.])

# %%
np.isnan(a1)
# Out:
# array([False, False, False,  True, False, False])

# %%
a2 = np.array(([1, 2, 3, np.inf, 5, 6]))
a2
# Out:
# array([ 1.,  2.,  3., inf,  5.,  6.])

# %%
np.isfinite(a2)
# Out:
# array([ True,  True,  True, False,  True,  True])

# %%
a3 = np.array([1, np.nan, 3, np.inf, 5])
a3
# Out:
# array([ 1., nan,  3., inf,  5.])

# %%
mask_arr = np.array([True, False, True, False, True])
mask_arr
# Out:
# array([ True, False,  True, False,  True])

# %%
a3[[True, False, True, False, True]], a3[mask_arr]
# Out:
# (array([1., 3., 5.]), array([1., 3., 5.]))

# %%
np.isfinite(a3)
# Out:
# array([ True, False,  True, False,  True])

# %%
a3[np.isfinite(a3)]
# Out:
# array([1., 3., 5.])

# %%
~np.isfinite(a3)
# Out:
# array([False,  True, False,  True, False])

# %%
a3[~np.isfinite(a3)]
# Out:
# array([nan, inf])

# %%
a4 = np.array([1, 2, np.nan, 4])
a4
# Out:
# array([ 1.,  2., nan,  4.])

# %%
np.isnan(a4)
# Out:
# array([False, False,  True, False])

# %%
# replace nan value
a4[np.isnan(a4)] = 1000
a4
# Out:
# array([   1.,    2., 1000.,    4.])

# %%
a3[np.isnan(a3)] = 1000
a3
# Out:
# array([   1., 1000.,    3.,   inf,    5.])

# %%
a3 = np.array([1, np.nan, 3, np.inf, 5])
a3
# Out:
# array([ 1., nan,  3., inf,  5.])

# %%
# replace non-finite value to 100 (~np.isfinite(a))
a3[~np.isfinite(a3)] = 100
a3
# Out:
# array([  1., 100.,   3., 100.,   5.])

# %%
a5 = np.array([
    [1, 2, np.nan],
    [4, np.nan, 6],
    [7, 8, 9]
])
a5
# Out:
# array([[ 1.,  2., nan],
#        [ 4., nan,  6.],
#        [ 7.,  8.,  9.]])

# %%
a5[np.isnan(a5)]
# Out:
# array([nan, nan])

# %%
np.where(np.isnan(a5)) # 1st row has nan value = 0, 2nd row has nan value, 2nd index has nan value = 2, 1st index has nan value = 1
# Out:
# (array([0, 1]), array([2, 1]))

# %%
np.where(np.isnan(a5))[1]
# Out:
# array([2, 1])

# %% [markdown]
# - first nan value has index (0, 2)
# - second nan value has index (1, 1)

# %%
a5
# Out:
# array([[ 1.,  2., nan],
#        [ 4., nan,  6.],
#        [ 7.,  8.,  9.]])

# %%
np.mean(a5)
# Out:
# np.float64(nan)

# %%
np.nanmean(a5)
# Out:
# np.float64(5.285714285714286)

# %% [markdown]
# - axis = 0 : column-wise operation
# - axis = 1 : row-wise operation

# %%
# col==> 1+4+7 = 12, 12/3 = 4 || row ==> 1+2+nan = 3/2 = 1.5
col_mean, row_mean = np.nanmean(a5, axis=0), np.nanmean(a5, axis=1)
col_mean, row_mean
# Out:
# (array([4. , 5. , 7.5]), array([1.5, 5. , 8. ]))

# %%
# nan value index's value
np.take(col_mean, np.where(np.isnan(a5))[1])
# Out:
# array([7.5, 5. ])

# %%
a5
# Out:
# array([[1. , 2. , 7.5],
#        [4. , 5. , 6. ],
#        [7. , 8. , 9. ]])

# %%
a5[np.isnan(a5)] = np.take(col_mean, np.where(np.isnan(a5))[1])
a5
# Out:
# array([[1. , 2. , 7.5],
#        [4. , 5. , 6. ],
#        [7. , 8. , 9. ]])

# %%
a5[np.isnan(a5)] = np.take(row_mean, np.where(np.isnan(a5))[0])
# np.array([nan, nan]) = np.array([1.5, 5])
a5
# Out:
# array([[1. , 2. , 1.5],
#        [4. , 5. , 6. ],
#        [7. , 8. , 9. ]])

# %%
# Out:
# array([], dtype=float64)
