# %% [markdown]
# # Handling Missing and Duplicate Data

# %% [markdown]
# ### Handling Missing Data

# %%
datapath = 'E:\TECH-AXIS\ClassTech\Class1\data\organizations-10000.csv'

# %%
import pandas as pd

# %%
# head: provides top 5 values 
df = pd.read_csv(datapath)
df.head()
# Out:
#    Index  Organization Id                         Name  \
# 0    NaN  522816eF8fdBE6d                 Mckinney PLC
# 1    2.0  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2    3.0  428B397eA2d7290                   Ruiz-Walls
# 3    4.0  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4    5.0  6CDCcdE3D0b7b44       Diaz, Robles and Haley
#
#                          Website  \
# 0               http://soto.com/
# 1      http://harding-duffy.com/
# 2         http://www.atkins.biz/
# 3           http://salazar.info/
# 4  https://www.brooks-scott.net/
#
#                                              Country  \
# 0                                          Sri Lanka
# 1                                            Namibia
# 2                                               Iran
# 3  British Indian Ocean Territory (Chagos Archipe...
# 4                                           Botswana
#
#                                   Description  Founded  \
# ...

# %%
df.isna()
# Out:
#       Index  Organization Id   Name  Website  Country  Description  Founded  \
# 0      True            False  False    False    False        False    False
# 1     False            False  False    False    False        False    False
# 2     False            False  False    False    False        False    False
# 3     False            False  False    False    False        False    False
# 4     False            False  False    False    False        False    False
# ...     ...              ...    ...      ...      ...          ...      ...
# 9995  False            False  False    False    False        False    False
# 9996  False            False  False    False    False        False    False
# 9997  False            False  False    False    False        False    False
# 9998  False            False  False    False    False        False    False
# 9999  False            False  False    False    False        False    False
#
#       Industry  Number of employees
# ...

# %%
# tail : ptovides last 5 values
df.tail()
# Out:
#         Index  Organization Id                       Name  \
# 9995   9996.0  2EE82AD1Cd045cd         Neal, Day and Wang
# 9996   9997.0  06f1568A2CaF04a  Barrett, Rojas and Adkins
# 9997   9998.0  B4B92A44e0331Bc             Franklin-Ayala
# 9998   9999.0  01D2539e270CEbd                Wolfe-Mckee
# 9999  10000.0  0D3b7DcFA21d92d                   Beck LLC
#
#                          Website       Country  \
# 9995         https://carson.net/    San Marino
# 9996  https://douglas-garza.com/  Turkmenistan
# 9997      http://www.torres.org/         Yemen
# 9998       http://www.parks.com/          Togo
# 9999  https://wagner-glover.com/       Georgia
#
#                                        Description  Founded  \
# 9995                 Team-oriented multimedia core     2013
# 9996             Cross-group dedicated methodology     2018
# 9997               Polarized exuding orchestration     1983
# 9998                  Balanced value-added ability     1975
# ...

# %%
True + False + True # True = 1, False = 0
# Out:
# 2

# %%
#sum = identify Nan values in each column
df.isna().sum()
# Out:
# Index                  1
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Description            0
# Founded                0
# Industry               0
# Number of employees    0
# dtype: int64

# %%
type(df['Index']), type(df[['Index']])
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %% [markdown]
# #### filtering records with NaN values in particular column

# %%
condition = df['Index'].isna() == True
#return series we have selected only aparticular column

# %%
df[condition]['Index', 'Organization Id'] # provide in list to extract column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\anoconda\envs\tech-axis\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Index', 'Organization Id')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ...

# %%
df['Index']=df['Index'].fillna(1.0) # hardcoded value should not be provided, just example
df
# Out:
#         Index  Organization Id                         Name  \
# 0         1.0  522816eF8fdBE6d                 Mckinney PLC
# 1         2.0  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2         3.0  428B397eA2d7290                   Ruiz-Walls
# 3         4.0  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4         5.0  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...       ...              ...                          ...
# 9995   9996.0  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996   9997.0  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997   9998.0  B4B92A44e0331Bc               Franklin-Ayala
# 9998   9999.0  01D2539e270CEbd                  Wolfe-Mckee
# 9999  10000.0  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website  \
# 0                  http://soto.com/
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
# df['Number of ']
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
import random
# random.randrange(1, 10)
#indices to replace nan
random.seed(42)
idx = random.choices(df.index, k=10)
idx
# Out:
# [6394, 250, 2750, 2232, 7364, 6766, 8921, 869, 4219, 297]

# %%
import numpy as np

# %%
arr = df['Number of employees'].to_numpy().astype('float')
arr, np.isnan(arr).sum()
# Out:
# (array([3930., 7871., 3095., ..., 8951., 2505., 4552.], shape=(10000,)),
#  np.int64(0))

# %%
# df['Number of employees'][idx] = np.nan
arr[idx] = np.nan

# %%
np.isnan(arr).sum()
# Out:
# np.int64(10)

# %%
df['Number of employees'] = arr

# %%
df.isna().sum()
# Out:
# Index                  1
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Description            0
# Founded                0
# Industry               0
# Number of employees    0
# dtype: int64

# %%
mean = df['Number of employees'].mean()
median = df['Number of employees'].median()
mean, median
# Out:
# (np.float64(4961.321), np.float64(4894.0))

# %%
# replace or  fill nan values
df['Number of employees'] = df['Number of employees'].fillna(mean)
df.isna().sum()
# Out:
# Index                  1
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Description            0
# Founded                0
# Industry               0
# Number of employees    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df = df.drop_duplicates()

# %%
df.loc[0].to_frame()
# Out:
#                                                    0
# Index                                            NaN
# Organization Id                      522816eF8fdBE6d
# Name                                    Mckinney PLC
# Website                             http://soto.com/
# Country                                    Sri Lanka
# Description          Synergized global system engine
# Founded                                         1988
# Industry                                       Dairy
# Number of employees                             3930

# %%
df.iloc[0]
# Out:
# Index                                              NaN
# Organization Id                        522816eF8fdBE6d
# Name                                      Mckinney PLC
# Website                               http://soto.com/
# Country                                      Sri Lanka
# Description            Synergized global system engine
# Founded                                           1988
# Industry                                         Dairy
# Number of employees                               3930
# Name: 0, dtype: object

# %%
# l = [[1.0, '522816eF8fdBE6d', 'Mckinney PLC', 'http://soto.com/', 'Sri Lanka', 'Synergized global system engine', 1988, 'Dairy', 3930]]
l = [df.iloc[0].values]
df2 = pd.DataFrame(l, columns=df.columns)
df2
# Out:
#    Index  Organization Id          Name           Website    Country  \
# 0    NaN  522816eF8fdBE6d  Mckinney PLC  http://soto.com/  Sri Lanka
#
#                        Description  Founded Industry  Number of employees
# 0  Synergized global system engine     1988    Dairy                 3930

# %%
df3 = pd.concat([df2, df], ignore_index=True)
df3
# Out:
#          Index  Organization Id                         Name  \
# 0          NaN  522816eF8fdBE6d                 Mckinney PLC
# 1          NaN  522816eF8fdBE6d                 Mckinney PLC
# 2          2.0  70C7FBD7e6Aa3Ea               Cunningham LLC
# 3          3.0  428B397eA2d7290                   Ruiz-Walls
# 4          4.0  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# ...        ...              ...                          ...
# 9996    9996.0  2EE82AD1Cd045cd           Neal, Day and Wang
# 9997    9997.0  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9998    9998.0  B4B92A44e0331Bc               Franklin-Ayala
# 9999    9999.0  01D2539e270CEbd                  Wolfe-Mckee
# 10000  10000.0  0D3b7DcFA21d92d                     Beck LLC
#
#                           Website  \
# 0                http://soto.com/
# 1                http://soto.com/
# 2       http://harding-duffy.com/
# 3          http://www.atkins.biz/
# 4            http://salazar.info/
# ...

# %%
df3.duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
df3.duplicated(keep='last') # in default keep = 'first'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df3.duplicated(keep='last') # in default keep = 'first'
#
# NameError: name 'df3' is not defined

# %%
df3[df3.duplicated(keep='last')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df3[df3.duplicated(keep='last')]
#
# NameError: name 'df3' is not defined

# %%
# identify the number of duplicated data 
df3.duplicated(['Organization Id']).sum()
# Out:
# np.int64(0)

# %%
#subset of column names
df3 = df3.drop_duplicates(['Organization Id'])
df3
# Out:
#          Index  Organization Id                         Name  \
# 0          1.0  522816eF8fdBE6d                 Mckinney PLC
# 2          2.0  70C7FBD7e6Aa3Ea               Cunningham LLC
# 3          3.0  428B397eA2d7290                   Ruiz-Walls
# 4          4.0  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 5          5.0  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...        ...              ...                          ...
# 9996    9996.0  2EE82AD1Cd045cd           Neal, Day and Wang
# 9997    9997.0  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9998    9998.0  B4B92A44e0331Bc               Franklin-Ayala
# 9999    9999.0  01D2539e270CEbd                  Wolfe-Mckee
# 10000  10000.0  0D3b7DcFA21d92d                     Beck LLC
#
#                              Website  \
# 0                   http://soto.com/
# 2          http://harding-duffy.com/
# 3             http://www.atkins.biz/
# 4               http://salazar.info/
# 5      https://www.brooks-scott.net/
# ...
