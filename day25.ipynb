# %% [markdown]
# # Matplotlib

# %%
# ! pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr = np.random.randint(0, 100, 200)
arr
# Out:
# array([56, 56, 62, 35, 58, 19, 36, 33, 60, 61, 77, 59, 11, 93, 94, 12, 96,
#        91, 67, 29, 41, 13, 81, 15, 39, 17, 89, 26, 41,  8, 29, 84,  7, 15,
#        52,  9, 47, 42,  2, 31, 73, 77, 43, 45, 69, 73, 20, 69, 38, 40, 41,
#        57, 19, 33, 89, 94, 39, 63,  3, 97, 45, 37, 25, 56, 11, 82, 62, 94,
#        21, 21, 19,  8,  6,  2, 88, 64, 44, 62, 62, 38, 37, 36, 40,  3, 74,
#        30, 25, 48, 89, 80, 47, 52, 53, 56, 10, 24, 86, 48, 50, 16, 81, 27,
#        88, 71, 87, 37, 75,  5,  3, 88, 77, 93, 78, 17,  1, 42, 15, 29, 24,
#         1, 95, 35, 31,  0, 88, 16, 49, 60, 66,  5, 16, 45, 15, 23, 90, 36,
#        39,  6,  8, 50, 53, 26, 97, 36, 18, 51, 34, 51, 20, 75, 43, 61, 59,
#        11, 41, 33, 58, 38, 44, 48, 86, 63, 55, 78, 86, 31, 81,  0, 87,  1,
#        93, 74, 66, 83,  4, 59, 13, 24, 58, 89, 70, 79, 93,  7, 80, 31, 81,
#         8,  1, 82, 77, 50, 75, 43, 41, 94,  5, 22, 82, 66], dtype=int32)

# %%
plt.plot(arr)

# %%
plt.scatter(np.arange(200),arr, s=10, c='red', marker='D')

# %%
arr2 = np.random.randint(0, 100, 200)
arr2
# Out:
# array([41, 29, 33, 56, 50, 65, 94, 79, 98, 67,  4, 29, 93, 93, 56,  2,  8,
#        69, 39, 66, 28, 15, 41, 31, 28,  6, 85, 52, 80, 35, 73, 87, 72, 41,
#        30, 48, 71, 80, 98, 78, 66, 94, 24, 48, 86, 73, 17,  9, 57, 62, 65,
#        79, 50, 50, 48, 24, 42,  7,  0, 57, 15, 98, 42, 52, 90,  4, 47, 87,
#        88,  0, 12,  7, 61, 78, 64, 79, 23, 59, 34,  4,  9, 98, 66, 43, 44,
#        87, 68, 83, 15, 28,  2, 48, 87, 41, 12, 67, 52, 54, 45, 21, 52, 39,
#        14, 69, 30, 83, 91, 41,  4, 62, 17, 87, 36, 29, 92, 13, 28, 22, 36,
#         7, 78, 18,  4,  5, 73, 21,  6, 90, 39, 29, 22, 46,  4, 97, 67, 81,
#        80, 19, 71, 80, 48, 66, 92, 57, 86, 73, 33, 38, 25, 98, 76, 26,  5,
#        23, 45, 86, 86, 93, 89, 22, 76, 50, 61, 25, 43, 21, 39, 51, 29, 87,
#        82, 20,  8, 42, 74,  2, 75, 70, 77, 23, 21, 37, 92, 49, 34, 26, 53,
#        79, 54, 74, 32, 87, 87, 20, 33, 74, 59, 92,  5, 92], dtype=int32)

# %%
# plt.scatter(np.arange(200),arr2, s=20, c='red', marker='D')
# plt.scatter(np.arange(200),arr2, s=20, c='green', marker='*')

# %%
plt.scatter(np.arange(200), arr, s=10, c='red', marker='D', label='male')
plt.scatter(np.arange(200), arr2, s=20, c='green', marker='*', label='female')
# include information in the plot
plt.legend()
plt.xlabel('earnings in thousands')
plt.ylabel('age')
plt.title('Earnings wrt Age')
# plt.grid(axis='x')
# plt.grid(axis='y')
plt.grid(axis='both') # default

# %%
# line plot: marker or points
# mec = marker edge color, mfc= face color
# plt.plot(arr)
arr7 = [2, 3, 4, 8, 1, 7]
plt.figure(figsize=(10, 4))
plt.plot(arr7, marker='*', mec='red', mfc='green')
plt.legend()
plt.xlabel('Number of people')
plt.ylabel('income in millions')
plt.title('Earnings wrt Number of people')
plt.grid(axis='both') # default
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_15884\2450850493.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#scatter plot without the marker
plt.plot(arr7, '*', mec='red', mfc='green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #scatter plot without the marker
# ----> 2 plt.plot(arr7, '*', mec='red', mfc='green')
#
# NameError: name 'arr7' is not defined

# %%
arr3 = np.random.randint(0, 100, 50)
arr3
# Out:
# array([68, 95,  8, 70, 47, 71, 70, 42, 23, 51, 84, 53, 56, 81, 62, 41,  3,
#        25, 65,  4,  3, 13,  0, 20, 91,  7, 90, 13, 93, 58, 49, 98, 77, 96,
#        50, 50, 96, 48, 36,  8, 20, 74,  2, 33, 77, 16, 28, 93, 46, 74],
#       dtype=int32)

# %%
plt.figure(figsize=(12, 5)) # width=12 and height=5
plt.bar(np.arange(50),arr3, width=0.8)
# Out:
# <BarContainer object of 50 artists>

# %%
plt.barh(np.arange(50),arr3)
# Out:
# <BarContainer object of 50 artists>

# %%
# arr = np.random.random(500)
arr4 = np.random.randint(1, 100, 10)
# arr = np.random.random(10)
arr4
# Out:
# array([66, 72, 47, 41, 96, 57, 29, 45, 95,  2], dtype=int32)

# %%
np.linspace(1, 100, 10)
# Out:
# array([  1.,  12.,  23.,  34.,  45.,  56.,  67.,  78.,  89., 100.])

# %%
plt.hist(arr, bins=10, color='grey')
# Out:
# (array([2., 2., 1., 1., 0., 0., 0., 2., 1., 1.]),
#  array([11. , 19.6, 28.2, 36.8, 45.4, 54. , 62.6, 71.2, 79.8, 88.4, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
np.linspace(0, 100, 10)
# Out:
# array([  0.        ,  11.11111111,  22.22222222,  33.33333333,
#         44.44444444,  55.55555556,  66.66666667,  77.77777778,
#         88.88888889, 100.        ])

# %%
plt.hist(arr, bins=10, color='grey')
# Out:
# (array([18., 19., 18., 19., 15., 21., 20., 27., 28., 15.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
arr5 = [1, 5, 6, 2, 7]
plt.pie(arr5)
# Out:
# ([<matplotlib.patches.Wedge at 0x20dd9722b90>,
# ...
#  [Text(1.0877139078161349, 0.1639464996373907, ''),
#   Text(0.5499999722395388, 0.9526279601903919, ''),
#   Text(-0.9910659367585292, 0.47727173496545894, ''),
#   Text(-0.8063568251311835, -0.7481902636123771, ''),
#   Text(0.5500003659264656, -0.9526277328950455, '')])

# %%
arr6 = np.array([1, 5, 6, 2, 7])
plt.pie(arr6, labels=arr.astype('str')) # set arrays elements as string labels
# Out:
# ([<matplotlib.patches.Wedge at 0x20dd9765210>,
# ...
#  [Text(1.0877139078161349, 0.1639464996373907, '1'),
#   Text(0.5499999722395388, 0.9526279601903919, '5'),
#   Text(-0.9910659367585292, 0.47727173496545894, '6'),
#   Text(-0.8063568251311835, -0.7481902636123771, '2'),
#   Text(0.5500003659264656, -0.9526277328950455, '7')])

# %%
arr6 = np.array([1, 5, 6, 2, 7])
plt.pie(arr6, labels=['car', 'van', 'cycle', 'bus', 'aircraft']) # set array
# Out:
# ([<matplotlib.patches.Wedge at 0x20dd845afd0>,
# ...
#  [Text(1.0877139078161349, 0.1639464996373907, 'car'),
#   Text(0.5499999722395388, 0.9526279601903919, 'van'),
#   Text(-0.9910659367585292, 0.47727173496545894, 'cycle'),
#   Text(-0.8063568251311835, -0.7481902636123771, 'bus'),
#   Text(0.5500003659264656, -0.9526277328950455, 'aircraft')])

# %%
arr6 = np.array([1, 5, 6, 2, 7])
plt.pie(
    arr6, 
    labels=['car', 'van', 'cycle', 'bus', 'aircraft'],
    explode=[0.0, 0.1, 0.0, 0.05, 0.0],    
    colors=['green', 'blue', 'orange', 'purple', 'maroon']
) # set array
# Out:
# ([<matplotlib.patches.Wedge at 0x20ddb352f50>,
# ...
#  [Text(1.0877139078161349, 0.1639464996373907, 'car'),
#   Text(0.5999999697158604, 1.039230502025882, 'van'),
#   Text(-0.9910659367585292, 0.47727173496545894, 'cycle'),
#   Text(-0.8430094080916918, -0.7821989119583942, 'bus'),
#   Text(0.5500003659264656, -0.9526277328950455, 'aircraft')])
