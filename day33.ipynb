# %% [markdown]
# ## Feature Scaling - Normalization and standardization

# %%
import pandas as pd

# %%
data = {
    'Age': [25, 40, 65, 30, 55],
    'Salary': [50000, 80000, 150000, 60000, 120000]
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary
# 0   25   50000
# 1   40   80000
# 2   65  150000
# 3   30   60000
# 4   55  120000

# %% [markdown]
# # Normalization
# - calculate min and max value of particular column
# - norm = (value - min) / (max - min)

# %%
age_min = df['Age'].min()
age_max = df['Age'].max()
age_min, age_max
# Out:
# (np.int64(25), np.int64(65))

# %%
# Normalzied age column
df['Age_norm'] = (df['Age'] - age_min) / (age_max - age_min)
df
# min value is 0 and max value is 1, all the other values comes in between 0 and 1
# Out:
#    Age  Salary  Age_norm
# 0   25   50000     0.000
# 1   40   80000     0.375
# 2   65  150000     1.000
# 3   30   60000     0.125
# 4   55  120000     0.750

# %%
# Normalized Salary column
salary_min = df['Salary'].min()
salary_max = df['Salary'].max()
df['Salary_norm'] = (df['Salary']-salary_min) / (salary_max - salary_min)
df
# Out:
#    Age  Salary  Age_norm  Salary_norm
# 0   25   50000     0.000          0.0
# 1   40   80000     0.375          0.3
# 2   65  150000     1.000          1.0
# 3   30   60000     0.125          0.1
# 4   55  120000     0.750          0.7

# %%
! pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in d:\anoconda\envs\tech-axis\lib\site-packages (from scikit-learn) (2.2.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 699.0 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/11.1 MB 699.0 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/11.1 MB 699.0 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/11.1 MB 532.8 kB/s eta 0:00:20
#    --- ------------------------------------ 1.0/11.1 MB 671.0 kB/s eta 0:00:16
#    --- ------------------------------------ 1.0/11.1 MB 671.0 kB/s eta 0:00:16
#    --- ------------------------------------ 1.0/11.1 MB 671.0 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/11.1 MB 536.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.1 MB 536.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.1 MB 536.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.1 MB 536.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.3/11.1 MB 536.9 kB/s eta 0:00:19
#    ----- ---------------------------------- 1.6/11.1 MB 432.4 kB/s eta 0:00:23
#    ----- ---------------------------------- 1.6/11.1 MB 432.4 kB/s eta 0:00:23
#    ----- ---------------------------------- 1.6/11.1 MB 432.4 kB/s eta 0:00:23
#    ----- ---------------------------------- 1.6/11.1 MB 432.4 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------ --------------------------------- 1.8/11.1 MB 405.9 kB/s eta 0:00:23
#    ------- -------------------------------- 2.1/11.1 MB 348.5 kB/s eta 0:00:26
#    ------- -------------------------------- 2.1/11.1 MB 348.5 kB/s eta 0:00:26
#    ------- -------------------------------- 2.1/11.1 MB 348.5 kB/s eta 0:00:26
#    ------- -------------------------------- 2.1/11.1 MB 348.5 kB/s eta 0:00:26
#    -------- ------------------------------- 2.4/11.1 MB 335.5 kB/s eta 0:00:27
#    -------- ------------------------------- 2.4/11.1 MB 335.5 kB/s eta 0:00:27
#    -------- ------------------------------- 2.4/11.1 MB 335.5 kB/s eta 0:00:27
#    --------- ------------------------------ 2.6/11.1 MB 344.8 kB/s eta 0:00:25
#    --------- ------------------------------ 2.6/11.1 MB 344.8 kB/s eta 0:00:25
#    ---------- ----------------------------- 2.9/11.1 MB 358.5 kB/s eta 0:00:24
#    ---------- ----------------------------- 2.9/11.1 MB 358.5 kB/s eta 0:00:24
#    ----------- ---------------------------- 3
6 MB/s eta 0:00:04
#    ----------------------- ---------------- 24.6/41.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------ --------------- 25.4/41.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------- -------------- 26.2/41.2 MB 4.6 MB/s eta 0:00:04
#    -------------------------- ------------- 27.3/41.2 MB 4.6 MB/s eta 0:00:04
#    --------------------------- ------------ 28.0/41.2 MB 4.5 MB/s eta 0:00:03
#    --------------------------- ------------ 28.6/41.2 MB 4.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.1/41.2 MB 4.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.6/41.2 MB 4.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.4/41.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------------ --------- 31.2/41.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------------- -------- 32.0/41.2 MB 4.2 MB/s eta 0:00:03
#    ------------------------------- -------- 32.5/41.2 MB 4.2 MB/s eta 0:00:03
#    -------------------------------- ------- 33.3/41.2 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 33.8/41.2 MB 4.2 MB/s eta 0:00:02
#    --------------------------------- ------ 34.3/41.2 MB 4.1 MB/s eta 0:00:02
#    --------------------------------- ------ 34.6/41.2 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.1/41.2 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.4/41.2 MB 4.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.2/41.2 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.7/41.2 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 37.2/41.2 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 37.7/41.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 38.3/41.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 38.8/41.2 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 39.3/41.2 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 39.6/41.2 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 40.1/41.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  40.6/41.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  40.6/41.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 3.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[['Age_norm_sk', 'Salary_norm_sk']] = scaler.fit_transform(df[['Age', 'Salary']])
df
# Out:
#    Age  Salary  Age_norm  Salary_norm  Age_norm_sk  Salary_norm_sk
# 0   25   50000     0.000          0.0        0.000             0.0
# 1   40   80000     0.375          0.3        0.375             0.3
# 2   65  150000     1.000          1.0        1.000             1.0
# 3   30   60000     0.125          0.1        0.125             0.1
# 4   55  120000     0.750          0.7        0.750             0.7

# %% [markdown]
# ## Standardization
# norm = (value - mean) / std

# %%
# age stan
data = {
    'Age': [25, 40, 65, 30, 55],
    'Salary': [50000, 80000, 150000, 60000, 120000]
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary
# 0   25   50000
# 1   40   80000
# 2   65  150000
# 3   30   60000
# 4   55  120000

# %%
age_mean = df['Age'].mean()
age_std = df['Age'].std()

df['Age_std'] = (df['Age'] - age_mean) / age_std
df
# Out:
#    Age  Salary   Age_std
# 0   25   50000 -1.070935
# 1   40   80000 -0.178489
# 2   65  150000  1.308921
# 3   30   60000 -0.773453
# 4   55  120000  0.713957

# %%
age_mean, df['Age_std'].mean()
# Out:
# (np.float64(43.0), np.float64(0.0))

# %%
salary_mean = df['Salary'].mean()
salary_std = df['Salary'].std()

df['Salary_std'] = (df['Salary'] - salary_mean) / salary_std
df
# Out:
#    Age  Salary   Age_std  Salary_std
# 0   25   50000 -1.070935   -0.998304
# 1   40   80000 -0.178489   -0.285230
# 2   65  150000  1.308921    1.378610
# 3   30   60000 -0.773453   -0.760612
# 4   55  120000  0.713957    0.665536

# %%
df['Salary'].mean(), df['Salary_std'].mean()
# Out:
# (np.float64(92000.0), np.float64(-2.2204460492503132e-17))

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
df[['Age_std_sk', 'Salary_std_sk']] = std_scaler.fit_transform(df[['Age', 'Salary']])
df
# Out:
#    Age  Salary   Age_std  Salary_std  Age_std_sk  Salary_std_sk
# 0   25   50000 -1.070935   -0.998304   -1.197342      -1.116137
# 1   40   80000 -0.178489   -0.285230   -0.199557      -0.318896
# 2   65  150000  1.308921    1.378610    1.463418       1.541333
# 3   30   60000 -0.773453   -0.760612   -0.864747      -0.850390
# 4   55  120000  0.713957    0.665536    0.798228       0.744092

# %%
# Skew
