# %% [markdown]
# Learning rate
# using loss
# gradient calculation
# update w, and b
# to approximate real data
#
# input: independent feature : can be one or many
# output: dependent feature : can be one or zero
#
# continuous data prediction-> regression task
# discrete data prediction -> classification task, 2 - binary classification, more than 2 -> multi class classification
#
# Activation Function
# Sigmoid F - change the input data
# Relu F - linearly seaprates
# input >= 0 -> output = input
# output <= 0 -> output = 0
#
# If 3 cases in Softmax
# higher probability, class = 0
# 0-0.6
# 1-0.3
# 2-0.1
# sum should always be 1

# %% [markdown]
# Supervised and Unsupervised Machine Learning
#
# If has target, Label, class its supervised else unsupervised
#
# In unsupervised - no target feature
#
# 1) Clustering/grouping
# Algo method
# examples : supermarket
#
# 2) Dimensionality Reduction: according to statistical value reduce the dimension,if number of dimension increases ML might act poor,
# number of data should me more to act accurately
# if number of feature high use dimensionality reduction.
